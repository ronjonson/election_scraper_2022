# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.getcwd(), "../scripts")))

# %%
from classes import Location, ElectionScraper

a = ElectionScraper(region="REGION VI", province="NEGROS OCCIDENTAL", city="CITY OF BACOLOD", barangay="TACULING", precinct="45010362")

a.scrape_data()
# Out:
# Scraping REGION data!
# value: REGION VI
# option.text: BARMM
# option.text: CORDILLERA ADMINISTRATIVE REGION
# option.text: NATIONAL CAPITAL REGION
# option.text:
# option.text: REGION I
# option.text: REGION II
# option.text: REGION III
# option.text: REGION IV-A
# option.text: REGION IV-B
# option.text: REGION IX
# option.text: REGION V
# option.text: REGION VI
# Scraping PROVINCE data!
# value: NEGROS OCCIDENTAL
# option.text: AKLAN
# option.text: ANTIQUE
# option.text: CAPIZ
# option.text: GUIMARAS
# option.text: ILOILO
# option.text: NEGROS OCCIDENTAL
# Scraping CITY data!
# value: CITY OF BACOLOD
# option.text: BINALBAGAN
# option.text: CALATRAVA
# option.text: CANDONI
# option.text: CAUAYAN
# option.text: CITY OF BACOLOD
# option.text: BINALBAGAN
# option.text: CALATRAVA
# option.text: CANDONI
# option.text: CAUAYAN
# option.text: CITY OF BACOLOD
# ---------------------------------------------------------------------------
# ElementClickInterceptedException          Traceback (most recent call last)
# File c:\Users\Neil\Documents\others\election\election_scraper_2022\scripts\classes.py:170, in ElectionScraper.scrape_data(self)
#     169 try:
# --> 170     self.select_option(f"//input[@placeholder='{DROPDOWN_PLACEHOLDER[key]}']", DROPDOWN_VALUES[key], value, self.driver)
#     171 except:
#
# File c:\Users\Neil\Documents\others\election\election_scraper_2022\scripts\classes.py:106, in ElectionScraper.select_option(self, dropdown_xpath, list_xpath, choice, driver)
#     104 WebDriverWait(driver, 10).until(
#     105     EC.element_to_be_clickable(option))
# --> 106 option.click()
#     107 return
#
# File c:\Users\Neil\anaconda3\envs\e_scraper\Lib\site-packages\selenium\webdriver\remote\webelement.py:94, in WebElement.click(self)
#      93 """Clicks the element."""
# ---> 94 self._execute(Command.CLICK_ELEMENT)
#
# File c:\Users\Neil\anaconda3\envs\e_scraper\Lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File c:\Users\Neil\anaconda3\envs\e_scraper\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#
# File c:\Users\Neil\anaconda3\envs\e_scraper\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: Element <li class="region-suggestion ng-binding ng-scope"> is not clickable at point (150,630) because another element <div class="container-fluid footer col-xs-12 text-right hidden-xs"> obscures it
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:199:5
# ElementClickInterceptedError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:351:5
# webdriverClickElement@chrome://remote/content/marionette/interaction.sys.mjs:177:11
# interaction.clickElement@chrome://remote/content/marionette/interaction.sys.mjs:136:11
# clickElement@chrome://remote/content/marionette/actors/MarionetteCommandsChild.sys.mjs:354:29
# receiveMessage@chrome://remote/content/marionette/actors/MarionetteCommandsChild.sys.mjs:230:31
#
#
# During handling of the above exception, another exception occurred:
#
# ElementClickInterceptedException          Traceback (most recent call last)
# Cell In[4], line 5
#       1 from classes import Location, ElectionScraper
#       3 a = ElectionScraper(region="REGION VI", province="NEGROS OCCIDENTAL", city="CITY OF BACOLOD", barangay="TACULING", precinct="45010362")
# ----> 5 a.scrape_data()
#
# File c:\Users\Neil\Documents\others\election\election_scraper_2022\scripts\classes.py:172, in ElectionScraper.scrape_data(self)
#     170         self.select_option(f"//input[@placeholder='{DROPDOWN_PLACEHOLDER[key]}']", DROPDOWN_VALUES[key], value, self.driver)
#     171     except:
# --> 172         self.select_option(DROPDOWN[key], DROPDOWN_VALUES[key], value, self.driver)
#     174     latest_key = key
#     176 loc_fields = fields(self.location)
#
# File c:\Users\Neil\Documents\others\election\election_scraper_2022\scripts\classes.py:106, in ElectionScraper.select_option(self, dropdown_xpath, list_xpath, choice, driver)
#     103     if option.text == choice:
#     104         WebDriverWait(driver, 10).until(
#     105             EC.element_to_be_clickable(option))
# --> 106         option.click()
#     107         return
#     109 raise ValueError(f'{choice} not found in list. Please choose the following options: {', '.join(options)}')
#
# File c:\Users\Neil\anaconda3\envs\e_scraper\Lib\site-packages\selenium\webdriver\remote\webelement.py:94, in WebElement.click(self)
#      92 def click(self) -> None:
#      93     """Clicks the element."""
# ---> 94     self._execute(Command.CLICK_ELEMENT)
#
# File c:\Users\Neil\anaconda3\envs\e_scraper\Lib\site-packages\selenium\webdriver\remote\webelement.py:395, in WebElement._execute(self, command, params)
#     393     params = {}
#     394 params["id"] = self._id
# --> 395 return self._parent.execute(command, params)
#
# File c:\Users\Neil\anaconda3\envs\e_scraper\Lib\site-packages\selenium\webdriver\remote\webdriver.py:354, in WebDriver.execute(self, driver_command, params)
#     352 response = self.command_executor.execute(driver_command, params)
#     353 if response:
# --> 354     self.error_handler.check_response(response)
#     355     response["value"] = self._unwrap_value(response.get("value", None))
#     356     return response
#
# File c:\Users\Neil\anaconda3\envs\e_scraper\Lib\site-packages\selenium\webdriver\remote\errorhandler.py:229, in ErrorHandler.check_response(self, response)
#     227         alert_text = value["alert"].get("text")
#     228     raise exception_class(message, screen, stacktrace, alert_text)  # type: ignore[call-arg]  # mypy is not smart enough here
# --> 229 raise exception_class(message, screen, stacktrace)
#
# ElementClickInterceptedException: Message: Element <li class="region-suggestion ng-binding ng-scope"> is not clickable at point (150,630) because another element <div class="container-fluid footer col-xs-12 text-right hidden-xs"> obscures it
# Stacktrace:
# RemoteError@chrome://remote/content/shared/RemoteError.sys.mjs:8:8
# WebDriverError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:199:5
# ElementClickInterceptedError@chrome://remote/content/shared/webdriver/Errors.sys.mjs:351:5
# webdriverClickElement@chrome://remote/content/marionette/interaction.sys.mjs:177:11
# interaction.clickElement@chrome://remote/content/marionette/interaction.sys.mjs:136:11
# clickElement@chrome://remote/content/marionette/actors/MarionetteCommandsChild.sys.mjs:354:29
# receiveMessage@chrome://remote/content/marionette/actors/MarionetteCommandsChild.sys.mjs:230:31
